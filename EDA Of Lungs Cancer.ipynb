# %% [markdown]
# # Lungs Cancer
# Lung cancer begins in the lungs and may spread to lymph nodes or other organs in the body, such as the brain. Cancer from other organs also may spread to the lungs. When cancer cells spread from one organ to another, they are called metastases.
#
# Lung cancers usually are grouped into two main types called small cell and non-small cell (non-small cell includes adenocarcinoma and squamous cell carcinoma). These types of lung cancer grow differently and are treated differently. Non-small cell lung cancer is more common than small cell lung cancer.

# %% [markdown]
# # Source of  data
# <img src='lungs.jpg' width="400" height="400">
# https://www.kaggle.com/datasets/yusufdede/lung-cancer-dataset/data

# %% [markdown]
#  ## OBJECTIVES
# * In this demo my objective is to find the relationship between smoke and age.
# * In this program my objective is o analyze the given lungs cancer data.

# %% [markdown]
# ## Importing Libraries

# %%
#importing numpy pandas mathplot and other methods
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#first read the data file
df= pd.read_csv('lung.csv')

# %%
#quick look to dataset 
df.head(15)
# Out:
#          Name      Surname  Age  Smokes  AreaQ  Alcohol  Result Sex
# 0        John         Wick   35       3      5        4       1   M
# 1        John  Constantine   27      20      2        5       1   M
# 2      Camela     Anderson   30       0      5        2       0   F
# 3        Alex       Telles   28       0      8        1       0   M
# 4       Diego     Maradona   68       4      5        6       1   M
# 5   Cristiano      Ronaldo   34       0     10        0       0   M
# 6      Mihail          Tal   58      15     10        0       0   M
# 7       Kathy        Bates   22      12      5        2       0   F
# 8      Nicole       Kidman   45       2      6        0       0   M
# 9         Ray      Milland   52      18      4        5       1   M
# 10    Fredric        March   33       4      8        0       0   M
# 11        Yul      Brynner   18      10      6        3       0   M
# 12       Joan     Crawford   25       2      5        1       0   M
# ...

# %%
#Print summary statistics
df.describe()
# Out:
#              Age     Smokes      AreaQ    Alcohol     Result
# count  59.000000  59.000000  59.000000  59.000000  59.000000
# mean   42.627119  15.067797   5.203390   3.237288   0.474576
# std    16.235230   7.984607   2.461984   2.380517   0.503640
# min    18.000000   0.000000   1.000000   0.000000   0.000000
# 25%    29.000000  10.000000   3.000000   1.000000   0.000000
# 50%    39.000000  15.000000   5.000000   3.000000   0.000000
# 75%    55.000000  20.000000   7.500000   5.000000   1.000000
# max    77.000000  34.000000  10.000000   8.000000   1.000000

# %% [markdown]
# * We have total 59 persons data.
# * The mean age of people is 42.
# * The standard deviation of age  is 16.235.
# * The minimum age of people is 18.
# * The maximum age of people is 77.
# * 50% or Median of people aged 39.
# * 75% of people aged 55.
# * 25% of people aged 29.

# %%
df.info()
#datatype------dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     59 non-null     object
#  1   Surname  59 non-null     object
#  2   Age      59 non-null     int64
#  3   Smokes   59 non-null     int64
#  4   AreaQ    59 non-null     int64
#  5   Alcohol  59 non-null     int64
#  6   Result   59 non-null     int64
#  7   Sex      59 non-null     object
# dtypes: int64(5), object(3)
# memory usage: 3.8+ KB

# %% [markdown]
# * datatype is dataframe.
# * here the dtype describes the datatype.
# * object=string,,,,,int64=number and in 64 is bits
# * Memory usuage gives us the idea about the space it takes
# * To change the string into number it helps to know
# * for eg the above shows object =3 i.e I know the no of string and same goes with integer
# * the non-null means no missing cell

# %%
# Inspect missing values in the dataset
print(df.isnull().values.sum())
# Out:
# 0

# %% [markdown]
# #### We see that this data do not contain any missing value

# %% [markdown]
# We are good to go for EDA Cycle

# %%
#Seaborn Histogram
sns.displot(data=df,x="Smokes")
#Add labels
plt.title('Smokes count')
plt.xlabel('Smokes')


plt.ylabel('Count')
# Out:
# Text(0.5694444444444446, 0.5, 'Count')

# %% [markdown]
# The above figure shows the histogram of smoke count.

# %%
sns.barplot(data=df,x="Smokes",y="Age",width=0.5)
# Out:
# <Axes: xlabel='Smokes', ylabel='Age'>

# %% [markdown]
# The above shows the barplot of smokes and age.

# %%
sns.displot(data=df,x="Age",kind="kde")

# %% [markdown]
# This above shows the age and its density.

# %%
# Create a scatterplot 
sns.scatterplot(x = df['Smokes'],y=df['Age'], hue=df['Sex'])

#Optionally ,add labels and a tittle
plt.title('Scatterplot of Smokes vs age')
plt.xlabel('Smokes')
plt.ylabel('Age')

#Show the plot
plt.show()

# %% [markdown]
# * The given scatter plot gives various info
# - Orange represents male and the other one female.
# - In year 20 and below there are few smokers and are male.
# - the hue represents to reflect the data in terms of gender .

# %%
# line plot 
sns.lineplot(x='Smokes',y='Age', data=df )
# Out:
# <Axes: xlabel='Smokes', ylabel='Age'>

# %% [markdown]
# *The above figure shows lineplot between smoke and age.

# %%
#box plot
sns.boxplot(y = 'Age',data= df, x= 'Sex')
plt.xlabel('SEX')
# Out:
# Text(0.5, 0, 'SEX')

# %% [markdown]
# * The above figure shows the bloxplot of age and smokes.
# # For female
# * it is left skewed
# * the max = 75 and min= 19
# * the median is 40
# * No outliner
#
# # For male
# * it is right skewed
# * the max=80 and min= 18
# * the median is 45
# * there is no outliner

# %%
#this is heat map pearson correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(16, 12))
sns.heatmap(corrmat, vmax=.8, square=True);
# Out:
# C:\Users\ANU'S LAPTOP\AppData\Local\Temp\ipykernel_11512\1752742378.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()

# %% [markdown]
# The above figure is pearson correlation matrix which shows "How each column are corelated to each other
#
# Here, Light color i.e see right scale 0.8 is highly corelated and darker color below -0.5 is not corelated
#
# This helps in feature selection also

# %%
plt.figure(figsize=(20,20))
plt.title('Pearsn Correlation of Features',size=15)
colormap= sns.diverging_palette(10,220,as_cmap = True)
sns.heatmap(df.corr(),square= True, annot=True,linewidths=0.1,vmax=1.0,linecolor='white',annot_kws={'fontsize':12})
plt.show()
# Out:
# C:\Users\ANU'S LAPTOP\AppData\Local\Temp\ipykernel_11512\2370769945.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),square= True, annot=True,linewidths=0.1,vmax=1.0,linecolor='white',annot_kws={'fontsize':12})

# %% [markdown]
# In above correlation matrix, we printed the number also so it will be easy for us to see which are highly corelated Value close to 1.00 is highly corelated

# %% [markdown]
# As per our objective,we see that "age" and "smokes" have value 0.054 which is above 0.0 and we can say that they are
# slightly correlated.

# %% [markdown]
# Since our objective is done hence our EDA finishes.
